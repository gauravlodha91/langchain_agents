# %%
234
# Out:
# 234

# %%
from dotenv import load_dotenv
import os
from langgraph.prebuilt import create_react_agent
from langgraph_supervisor import create_supervisor

# Load environment variables
load_dotenv()

from langchain_cohere import ChatCohere



from dotenv import load_dotenv
import os
from langgraph.prebuilt import create_react_agent

# %%
chat_model = ChatCohere(
    cohere_api_key=os.getenv("COHERE_API_KEY"),
    model="command-r-plus",  # Cohere's latest model
    temperature=0.7
)

# %%
from langchain_core.tools import tool

@tool
def book_hotel_tool(hotel_name: str) -> str:
    """Book a hotel reservation
    
    Args:
        hotel_name: Name of the hotel to book
    """
    return f"Successfully booked a stay at {hotel_name}."

@tool  
def book_flight_tool(from_airport: str, to_airport: str) -> str:
    """Book a flight ticket
    
    Args:
        from_airport: Departure airport code
        to_airport: Arrival airport code
    """
    return f"Successfully booked a flight from {from_airport} to {to_airport}."

# %%
# First, let's fix the agent creation
flight_assistant = create_react_agent(
    model=chat_model,
    tools=[book_flight_tool],
    prompt="You are a flight booking assistant",
    name="flight_assistant"  # Added name parameter
)

hotel_assistant = create_react_agent(
    model=chat_model,
    tools=[book_hotel_tool],
    prompt="You are a hotel booking assistant",
    name="hotel_assistant"  # Added name parameter
)

# %% [markdown]
# #### LLM based Routing example

# %%
from langchain_core.prompts import ChatPromptTemplate
from typing import Annotated, TypedDict, Literal
from langchain_core.messages import HumanMessage, AIMessage, BaseMessage
from langgraph.graph import StateGraph, START, END

# Define the state - this is passed between all nodes
class TravelState(TypedDict):
    messages: Annotated[list[BaseMessage], "The conversation messages"]
    current_agent: Annotated[str, "Currently active agent"]

# Define a routing prompt template
router_prompt = ChatPromptTemplate.from_messages([
    ("system", """You are a smart routing assistant that directs user requests to the appropriate service:
    - flight_assistant: for anything related to flight bookings, air travel, or airports
    - hotel_assistant: for anything related to hotel bookings, accommodations, or stays
    - END: if the request doesn't match either service
    
    Respond ONLY with one of these three options: flight_assistant, hotel_assistant, or END"""),
    ("user", "{message}")
])

def llm_route_request(state: TravelState) -> Literal["flight_assistant", "hotel_assistant", END]:
    """Smart router using LLM to understand and route requests"""
    print(f"🔄 ROUTER: Current state has {len(state['messages'])} messages")
    
    if not state["messages"]:
        print("🔄 ROUTER: No messages, ending")
        return END
    
    last_message = state["messages"][-1]
    print(f"🔄 ROUTER: Last message type: {type(last_message).__name__}")
    print(f"🔄 ROUTER: Message content: {last_message.content}")
    
    # Use LLM to determine routing
    chain = router_prompt | chat_model
    response = chain.invoke({"message": last_message.content})
    
    print("----------------------------------------------------------------------")
    print(f"response --> {response}")
    print("_________________________________________________________________________")
    route = response.content.strip().lower()
    
    print(f"🤖 LLM Router decided: {route}")
    
    if route == "flight_assistant":
        print("✈️  ROUTER: Routing to flight_assistant")
        return "flight_assistant"
    elif route == "hotel_assistant":
        print("🏨 ROUTER: Routing to hotel_assistant")
        return "hotel_assistant"
    else:
        print("❓ ROUTER: No clear match, ending")
        return END

# Update the workflow to use the LLM router
# ... existing workflow setup code ...
# Wrapper functions for your agents (required for StateGraph)
def flight_node(state: TravelState):
    """Flight assistant node"""
    print("✈️  FLIGHT_NODE: Starting flight assistant")
    print(f"✈️  FLIGHT_NODE: Input state messages: {len(state['messages'])}")
    
    # Call your existing flight assistant
    result = flight_assistant.invoke({"messages": state["messages"]})
    
    print(f"✈️  FLIGHT_NODE: Flight assistant returned {len(result['messages'])} messages")
    
    # Return updated state
    return {
        "messages": result["messages"],
        "current_agent": "flight_assistant"
    }

def hotel_node(state: TravelState):
    """Hotel assistant node"""
    print("🏨 HOTEL_NODE: Starting hotel assistant")
    print(f"🏨 HOTEL_NODE: Input state messages: {len(state['messages'])}")
    
    # Call your existing hotel assistant  
    result = hotel_assistant.invoke({"messages": state["messages"]})
    
    print(f"🏨 HOTEL_NODE: Hotel assistant returned {len(result['messages'])} messages")
    
    # Return updated state
    return {
        "messages": result["messages"],
        "current_agent": "hotel_assistant"
    }


# Create the StateGraph
print("🏗️  Creating StateGraph...")
workflow = StateGraph(TravelState)

# Add nodes
print("🏗️  Adding nodes...")
workflow.add_node("flight_assistant", flight_node)
workflow.add_node("hotel_assistant", hotel_node)

workflow.add_conditional_edges(
    START,
    llm_route_request,  # Use the LLM router instead of keyword matching
    {
        "flight_assistant": "flight_assistant",
        "hotel_assistant": "hotel_assistant",
        END: END
    }
)



# After each agent runs, go to END
workflow.add_edge("flight_assistant", END)
workflow.add_edge("hotel_assistant", END)

# Compile the graph
print("🏗️  Compiling graph...")
app = workflow.compile()

# Test it!
print("\n🧪 TESTING THE GRAPH:")

# Test 1: Flight request
print("\n--- Test 1: Flight Request ---")
initial_state = {
    "messages": [HumanMessage(content="I need to book a flight from LAX to JFK")],
    "current_agent": ""
}
print(f"🧪 Initial state: {initial_state}")

result = app.invoke(initial_state)
print(f"🧪 Final result: {result}")

# Test 2: Hotel request  
print("\n--- Test 2: Hotel Request ---")
initial_state = {
    "messages": [HumanMessage(content="I need to book a hotel in New York")],
    "current_agent": ""
}
print(f"🧪 Initial state: {initial_state}")

result = app.invoke(initial_state)
print(f"🧪 Final result: {result}")


# ... rest of the existing code ...
# Out:
# 🏗️  Creating StateGraph...
# 🏗️  Adding nodes...
# 🏗️  Compiling graph...
#
# 🧪 TESTING THE GRAPH:
#
# --- Test 1: Flight Request ---
# 🧪 Initial state: {'messages': [HumanMessage(content='I need to book a flight from LAX to JFK', additional_kwargs={}, response_metadata={})], 'current_agent': ''}
# 🔄 ROUTER: Current state has 1 messages
# 🔄 ROUTER: Last message type: HumanMessage
# 🔄 ROUTER: Message content: I need to book a flight from LAX to JFK
# ----------------------------------------------------------------------
# response --> content='flight_assistant' additional_kwargs={'id': '142244ff-abf5-454c-9bea-28ddaa26db88', 'finish_reason': 'COMPLETE', 'content': 'flight_assistant', 'token_count': {'input_tokens': 102.0, 'output_tokens': 3.0}} response_metadata={'id': '142244ff-abf5-454c-9bea-28ddaa26db88', 'finish_reason': 'COMPLETE', 'content': 'flight_assistant', 'token_count': {'input_tokens': 102.0, 'output_tokens': 3.0}} id='run--ab65deab-d982-46c5-b115-74180e711024-0' usage_metadata={'input_tokens': 102, 'output_tokens': 3, 'total_tokens': 105}
# _________________________________________________________________________
# 🤖 LLM Router decided: flight_assistant
# ✈️  ROUTER: Routing to flight_assistant
# ✈️  FLIGHT_NODE: Starting flight assistant
# ✈️  FLIGHT_NODE: Input state messages: 1
# ✈️  FLIGHT_NODE: Flight assistant returned 4 messages
# 🧪 Final result: {'messages': [HumanMessage(content='I need to book a flight from LAX to JFK', additional_kwargs={}, response_metadata={}, id='70f258d6-32ff-4fc0-a29d-c8d96bfcecbd'), AIMessage(content='I will book a flight from LAX to JFK and relay the confirmation to the user.', additional_kwargs={'id': '64c14bcf-c95b-427b-b15f-92832eb53e4f', 'finish_reason': 'TOOL_CALL', 'tool_plan': 'I will book a flight from LAX to JFK and relay the confirmation to the user.', 'tool_calls': [{'id': 'book_flight_tool_16tmjps0wq19', 'type': 'function', 'function': {'name': 'book_flight_tool', 'arguments': '{"from_airport":"LAX","to_airport":"JFK"}'}}], 'token_count': {'input_tokens': 813.0, 'output_tokens': 77.0}}, response_metadata={'id': '64c14bcf-c95b-427b-b15f-92832eb53e4f', 'finish_reason': 'TOOL_CALL', 'tool_plan': 'I will book a flight from LAX to JFK and relay the confirmation to the user.', 'tool_calls': [{'id': 'book_flight_tool_16tmjps0wq19', 'type': 'function', 'function': {'name': 'book_flight_tool', 'arguments': '{"from_airport":"LAX","to_airport":"JFK"}'}}], 'token_count': {'input_tokens': 813.0, 'output_tokens': 77.0}}, name='flight_assistant', id='run--6cb20314-063b-4441-9760-2ba504302c67-0', tool_calls=[{'name': 'book_flight_tool', 'args': {'from_airport': 'LAX', 'to_airport': 'JFK'}, 'id': 'book_flight_tool_16tmjps0wq19', 'type': 'tool_call'}], usage_metadata={'input_tokens': 813, 'output_tokens': 77, 'total_tokens': 890}), ToolMessage(content='Successfully booked a flight from LAX to JFK.', name='book_flight_tool', id='e5cd670b-c707-4f7c-8ebf-f5ebf576c58a', tool_call_id='book_flight_tool_16tmjps0wq19'), AIMessage(content='Your flight from LAX to JFK has been successfully booked.', additional_kwargs={'id': '7c5d3e08-0672-4dc8-941a-af78dfe1bf1e', 'finish_reason': 'COMPLETE', 'content': 'Your flight from LAX to JFK has been successfully booked.', 'citations': [Citation(start=37, end=56, text='successfully booked', sources=[ToolSource(type='tool', id='book_flight_tool_16tmjps0wq19:0', tool_output={'output': 'Successfully booked a flight from LAX to JFK.'})], content_index=None, type='TEXT_CONTENT')], 'token_count': {'input_tokens': 931.0, 'output_tokens': 57.0}}, response_metadata={'id': '7c5d3e08-0672-4dc8-941a-af78dfe1bf1e', 'finish_reason': 'COMPLETE', 'content': 'Your flight from LAX to JFK has been successfully booked.', 'citations': [Citation(start=37, end=56, text='successfully booked', sources=[ToolSource(type='tool', id='book_flight_tool_16tmjps0wq19:0', tool_output={'output': 'Successfully booked a flight from LAX to JFK.'})], content_index=None, type='TEXT_CONTENT')], 'token_count': {'input_tokens': 931.0, 'output_tokens': 57.0}}, name='flight_assistant', id='run--0ad8fb0f-78e8-48d7-9ab1-9642817069ec-0', usage_metadata={'input_tokens': 931, 'output_tokens': 57, 'total_tokens': 988})], 'current_agent': 'flight_assistant'}
#
# --- Test 2: Hotel Request ---
# 🧪 Initial state: {'messages': [HumanMessage(content='I need to book a hotel in New York', additional_kwargs={}, response_metadata={})], 'current_agent': ''}
# 🔄 ROUTER: Current state has 1 messages
# 🔄 ROUTER: Last message type: HumanMessage
# 🔄 ROUTER: Message content: I need to book a hotel in New York
# ----------------------------------------------------------------------
# response --> content='hotel_assistant' additional_kwargs={'id': '3f86ab65-ba3f-46ca-b81c-b0ec09b7a419', 'finish_reason': 'COMPLETE', 'content': 'hotel_assistant', 'token_count': {'input_tokens': 100.0, 'output_tokens': 3.0}} response_metadata={'id': '3f86ab65-ba3f-46ca-b81c-b0ec09b7a419', 'finish_reason': 'COMPLETE', 'content': 'hotel_assistant', 'token_count': {'input_tokens': 100.0, 'output_tokens': 3.0}} id='run--912f6d63-2465-40f2-aded-bae2a038e82a-0' usage_metadata={'input_tokens': 100, 'output_tokens': 3, 'total_tokens': 103}
# _________________________________________________________________________
# 🤖 LLM Router decided: hotel_assistant
# 🏨 ROUTER: Routing to hotel_assistant
# 🏨 HOTEL_NODE: Starting hotel assistant
# 🏨 HOTEL_NODE: Input state messages: 1
# 🏨 HOTEL_NODE: Hotel assistant returned 2 messages
# 🧪 Final result: {'messages': [HumanMessage(content='I need to book a hotel in New York', additional_kwargs={}, response_metadata={}, id='bb4b2dc5-e133-4e5a-8cff-c2b7da426285'), AIMessage(content='Which hotel in New York would you like me to book?', additional_kwargs={'id': 'bee86c9d-b338-4408-b5ad-b1c9be16af0a', 'finish_reason': 'COMPLETE', 'content': 'Which hotel in New York would you like me to book?', 'token_count': {'input_tokens': 924.0, 'output_tokens': 43.0}}, response_metadata={'id': 'bee86c9d-b338-4408-b5ad-b1c9be16af0a', 'finish_reason': 'COMPLETE', 'content': 'Which hotel in New York would you like me to book?', 'token_count': {'input_tokens': 924.0, 'output_tokens': 43.0}}, name='hotel_assistant', id='run--a6fd5674-6b21-4b3d-91d4-b268210996cd-0', usage_metadata={'input_tokens': 924, 'output_tokens': 43, 'total_tokens': 967})], 'current_agent': 'hotel_assistant'}

# %% [markdown]
# #### Simple routing function - decides which agent to call

# %%
# from typing import Annotated, TypedDict, Literal
# from langchain_core.messages import HumanMessage, AIMessage, BaseMessage
# from langgraph.graph import StateGraph, START, END

# # Define the state - this is passed between all nodes
# class TravelState(TypedDict):
#     messages: Annotated[list[BaseMessage], "The conversation messages"]
#     current_agent: Annotated[str, "Currently active agent"]

# # Simple routing function - decides which agent to call
# def route_request(state: TravelState) -> Literal["flight_assistant", "hotel_assistant", END]:
#     """Simple router based on keywords in the last message"""
#     print(f"🔄 ROUTER: Current state has {len(state['messages'])} messages")
    
#     if not state["messages"]:
#         print("🔄 ROUTER: No messages, ending")
#         return END
    
#     last_message = state["messages"][-1]
#     print(f"🔄 ROUTER: Last message type: {type(last_message).__name__}")
#     print(f"🔄 ROUTER: Message content: {last_message.content}")
    
#     # Simple keyword-based routing
#     content = last_message.content.lower()
    
#     if "flight" in content or "airport" in content or "fly" in content:
#         print("✈️  ROUTER: Routing to flight_assistant")
#         return "flight_assistant"
#     elif "hotel" in content or "room" in content or "stay" in content:
#         print("🏨 ROUTER: Routing to hotel_assistant") 
#         return "hotel_assistant"
#     else:
#         print("❓ ROUTER: No clear match, ending")
#         return END

# # Wrapper functions for your agents (required for StateGraph)
# def flight_node(state: TravelState):
#     """Flight assistant node"""
#     print("✈️  FLIGHT_NODE: Starting flight assistant")
#     print(f"✈️  FLIGHT_NODE: Input state messages: {len(state['messages'])}")
    
#     # Call your existing flight assistant
#     result = flight_assistant.invoke({"messages": state["messages"]})
    
#     print(f"✈️  FLIGHT_NODE: Flight assistant returned {len(result['messages'])} messages")
    
#     # Return updated state
#     return {
#         "messages": result["messages"],
#         "current_agent": "flight_assistant"
#     }

# def hotel_node(state: TravelState):
#     """Hotel assistant node"""
#     print("🏨 HOTEL_NODE: Starting hotel assistant")
#     print(f"🏨 HOTEL_NODE: Input state messages: {len(state['messages'])}")
    
#     # Call your existing hotel assistant  
#     result = hotel_assistant.invoke({"messages": state["messages"]})
    
#     print(f"🏨 HOTEL_NODE: Hotel assistant returned {len(result['messages'])} messages")
    
#     # Return updated state
#     return {
#         "messages": result["messages"],
#         "current_agent": "hotel_assistant"
#     }

# # Create the StateGraph
# print("🏗️  Creating StateGraph...")
# workflow = StateGraph(TravelState)

# # Add nodes
# print("🏗️  Adding nodes...")
# workflow.add_node("flight_assistant", flight_node)
# workflow.add_node("hotel_assistant", hotel_node)

# # Add edges
# print("🏗️  Adding edges...")
# # Start by routing the initial request
# workflow.add_conditional_edges(
#     START,  # From the start
#     route_request,  # Use this function to decide where to go
#     {
#         "flight_assistant": "flight_assistant",  # If returns "flight_assistant", go to flight node
#         "hotel_assistant": "hotel_assistant",    # If returns "hotel_assistant", go to hotel node  
#         END: END  # If returns END, finish
#     }
# )

# # After each agent runs, go to END
# workflow.add_edge("flight_assistant", END)
# workflow.add_edge("hotel_assistant", END)

# # Compile the graph
# print("🏗️  Compiling graph...")
# app = workflow.compile()

# # Test it!
# print("\n🧪 TESTING THE GRAPH:")

# # Test 1: Flight request
# print("\n--- Test 1: Flight Request ---")
# initial_state = {
#     "messages": [HumanMessage(content="I need to book a flight from LAX to JFK")],
#     "current_agent": ""
# }
# print(f"🧪 Initial state: {initial_state}")

# result = app.invoke(initial_state)
# print(f"🧪 Final result: {result}")

# # Test 2: Hotel request  
# print("\n--- Test 2: Hotel Request ---")
# initial_state = {
#     "messages": [HumanMessage(content="I need to book a hotel in New York")],
#     "current_agent": ""
# }
# print(f"🧪 Initial state: {initial_state}")

# result = app.invoke(initial_state)
# print(f"🧪 Final result: {result}")
# Out:
# 🏗️  Creating StateGraph...
# 🏗️  Adding nodes...
# 🏗️  Adding edges...
# 🏗️  Compiling graph...
#
# 🧪 TESTING THE GRAPH:
#
# --- Test 1: Flight Request ---
# 🧪 Initial state: {'messages': [HumanMessage(content='I need to book a flight from LAX to JFK', additional_kwargs={}, response_metadata={})], 'current_agent': ''}
# 🔄 ROUTER: Current state has 1 messages
# 🔄 ROUTER: Last message type: HumanMessage
# 🔄 ROUTER: Message content: I need to book a flight from LAX to JFK
# ✈️  ROUTER: Routing to flight_assistant
# ✈️  FLIGHT_NODE: Starting flight assistant
# ✈️  FLIGHT_NODE: Input state messages: 1
# ✈️  FLIGHT_NODE: Flight assistant returned 4 messages
# 🧪 Final result: {'messages': [HumanMessage(content='I need to book a flight from LAX to JFK', additional_kwargs={}, response_metadata={}, id='3f84bd14-52d3-40a4-b2a5-f82b3eff8611'), AIMessage(content='I will book a flight from LAX to JFK.', additional_kwargs={'id': '78da1a8a-0148-4ebf-932c-fae0991ccf18', 'finish_reason': 'TOOL_CALL', 'tool_plan': 'I will book a flight from LAX to JFK.', 'tool_calls': [{'id': 'book_flight_tool_b5km7q78wwyp', 'type': 'function', 'function': {'name': 'book_flight_tool', 'arguments': '{"from_airport":"LAX","to_airport":"JFK"}'}}], 'token_count': {'input_tokens': 813.0, 'output_tokens': 70.0}}, response_metadata={'id': '78da1a8a-0148-4ebf-932c-fae0991ccf18', 'finish_reason': 'TOOL_CALL', 'tool_plan': 'I will book a flight from LAX to JFK.', 'tool_calls': [{'id': 'book_flight_tool_b5km7q78wwyp', 'type': 'function', 'function': {'name': 'book_flight_tool', 'arguments': '{"from_airport":"LAX","to_airport":"JFK"}'}}], 'token_count': {'input_tokens': 813.0, 'output_tokens': 70.0}}, name='flight_assistant', id='run--7a58a1ba-96c6-4088-83b8-3a0cb5c37942-0', tool_calls=[{'name': 'book_flight_tool', 'args': {'from_airport': 'LAX', 'to_airport': 'JFK'}, 'id': 'book_flight_tool_b5km7q78wwyp', 'type': 'tool_call'}], usage_metadata={'input_tokens': 813, 'output_tokens': 70, 'total_tokens': 883}), ToolMessage(content='Successfully booked a flight from LAX to JFK.', name='book_flight_tool', id='59e14302-5be6-4f0b-8924-e590456eedc0', tool_call_id='book_flight_tool_b5km7q78wwyp'), AIMessage(content='Your flight from LAX to JFK has been booked successfully.', additional_kwargs={'id': 'f1acda98-7c08-417a-9797-a7e5299946e1', 'finish_reason': 'COMPLETE', 'content': 'Your flight from LAX to JFK has been booked successfully.', 'citations': [Citation(start=37, end=56, text='booked successfully', sources=[ToolSource(type='tool', id='book_flight_tool_b5km7q78wwyp:0', tool_output={'output': 'Successfully booked a flight from LAX to JFK.'})], content_index=None, type='TEXT_CONTENT')], 'token_count': {'input_tokens': 924.0, 'output_tokens': 57.0}}, response_metadata={'id': 'f1acda98-7c08-417a-9797-a7e5299946e1', 'finish_reason': 'COMPLETE', 'content': 'Your flight from LAX to JFK has been booked successfully.', 'citations': [Citation(start=37, end=56, text='booked successfully', sources=[ToolSource(type='tool', id='book_flight_tool_b5km7q78wwyp:0', tool_output={'output': 'Successfully booked a flight from LAX to JFK.'})], content_index=None, type='TEXT_CONTENT')], 'token_count': {'input_tokens': 924.0, 'output_tokens': 57.0}}, name='flight_assistant', id='run--1542fe62-fba3-4182-bf0c-a699afd452f0-0', usage_metadata={'input_tokens': 924, 'output_tokens': 57, 'total_tokens': 981})], 'current_agent': 'flight_assistant'}
#
# --- Test 2: Hotel Request ---
# 🧪 Initial state: {'messages': [HumanMessage(content='I need to book a hotel in New York', additional_kwargs={}, response_metadata={})], 'current_agent': ''}
# 🔄 ROUTER: Current state has 1 messages
# 🔄 ROUTER: Last message type: HumanMessage
# 🔄 ROUTER: Message content: I need to book a hotel in New York
# 🏨 ROUTER: Routing to hotel_assistant
# 🏨 HOTEL_NODE: Starting hotel assistant
# 🏨 HOTEL_NODE: Input state messages: 1
# 🏨 HOTEL_NODE: Hotel assistant returned 4 messages
# 🧪 Final result: {'messages': [HumanMessage(content='I need to book a hotel in New York', additional_kwargs={}, response_metadata={}, id='2d53d061-8349-4e8b-adfc-11e5f27f970d'), AIMessage(content='I will use the booking tool to book a hotel in New York.', additional_kwargs={'id': '657b779e-3cb7-4fc3-a38a-088ff57c3d60', 'finish_reason': 'TOOL_CALL', 'tool_plan': 'I will use the booking tool to book a hotel in New York.', 'tool_calls': [{'id': 'book_hotel_tool_vqja4xd290yk', 'type': 'function', 'function': {'name': 'book_hotel_tool', 'arguments': '{"hotel_name":"New York"}'}}], 'token_count': {'input_tokens': 787.0, 'output_tokens': 61.0}}, response_metadata={'id': '657b779e-3cb7-4fc3-a38a-088ff57c3d60', 'finish_reason': 'TOOL_CALL', 'tool_plan': 'I will use the booking tool to book a hotel in New York.', 'tool_calls': [{'id': 'book_hotel_tool_vqja4xd290yk', 'type': 'function', 'function': {'name': 'book_hotel_tool', 'arguments': '{"hotel_name":"New York"}'}}], 'token_count': {'input_tokens': 787.0, 'output_tokens': 61.0}}, name='hotel_assistant', id='run--fab986b8-59b6-4b66-a062-ca9be4a8f18f-0', tool_calls=[{'name': 'book_hotel_tool', 'args': {'hotel_name': 'New York'}, 'id': 'book_hotel_tool_vqja4xd290yk', 'type': 'tool_call'}], usage_metadata={'input_tokens': 787, 'output_tokens': 61, 'total_tokens': 848}), ToolMessage(content='Successfully booked a stay at New York.', name='book_hotel_tool', id='a6df4b14-4a48-4442-ae67-0ac25930c3ac', tool_call_id='book_hotel_tool_vqja4xd290yk'), AIMessage(content="I've successfully booked a stay at New York.", additional_kwargs={'id': '491727c9-0101-4e36-838d-699020c1569b', 'finish_reason': 'COMPLETE', 'content': "I've successfully booked a stay at New York.", 'citations': [Citation(start=5, end=43, text='successfully booked a stay at New York', sources=[ToolSource(type='tool', id='book_hotel_tool_vqja4xd290yk:0', tool_output={'output': 'Successfully booked a stay at New York.'})], content_index=None, type='TEXT_CONTENT')], 'token_count': {'input_tokens': 887.0, 'output_tokens': 53.0}}, response_metadata={'id': '491727c9-0101-4e36-838d-699020c1569b', 'finish_reason': 'COMPLETE', 'content': "I've successfully booked a stay at New York.", 'citations': [Citation(start=5, end=43, text='successfully booked a stay at New York', sources=[ToolSource(type='tool', id='book_hotel_tool_vqja4xd290yk:0', tool_output={'output': 'Successfully booked a stay at New York.'})], content_index=None, type='TEXT_CONTENT')], 'token_count': {'input_tokens': 887.0, 'output_tokens': 53.0}}, name='hotel_assistant', id='run--c6ee0c75-da85-4522-89c4-c9f54acb4d41-0', usage_metadata={'input_tokens': 887, 'output_tokens': 53, 'total_tokens': 940})], 'current_agent': 'hotel_assistant'}
